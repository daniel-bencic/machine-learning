# %%
import pandas as pd
import numpy as np
import matplotlib

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
cols = [ "CRIM" , "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "TGT"]
boston = pd.read_csv(url, sep = ' ', skipinitialspace = True, header = None, names = cols, index_col = False )

# %%
boston.isna().any()
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# TGT        False
# dtype: bool

# %%
boston.duplicated().any()
# Out:
# False

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
pd.plotting.scatter_matrix(boston, figsize=(14,14), marker='o');

# %%
for c in cols:
    print(str(c))
    print(boston[c].unique())
# Out:
# CRIM
# [6.32000e-03 2.73100e-02 2.72900e-02 3.23700e-02 6.90500e-02 2.98500e-02
#  8.82900e-02 1.44550e-01 2.11240e-01 1.70040e-01 2.24890e-01 1.17470e-01
#  9.37800e-02 6.29760e-01 6.37960e-01 6.27390e-01 1.05393e+00 7.84200e-01
#  8.02710e-01 7.25800e-01 1.25179e+00 8.52040e-01 1.23247e+00 9.88430e-01
#  7.50260e-01 8.40540e-01 6.71910e-01 9.55770e-01 7.72990e-01 1.00245e+00
#  1.13081e+00 1.35472e+00 1.38799e+00 1.15172e+00 1.61282e+00 6.41700e-02
#  9.74400e-02 8.01400e-02 1.75050e-01 2.76300e-02 3.35900e-02 1.27440e-01
#  1.41500e-01 1.59360e-01 1.22690e-01 1.71420e-01 1.88360e-01 2.29270e-01
#  2.53870e-01 2.19770e-01 8.87300e-02 4.33700e-02 5.36000e-02 4.98100e-02
#  1.36000e-02 1.31100e-02 2.05500e-02 1.43200e-02 1.54450e-01 1.03280e-01
#  1.49320e-01 1.71710e-01 1.10270e-01 1.26500e-01 1.95100e-02 3.58400e-02
#  4.37900e-02 5.78900e-02 1.35540e-01 1.28160e-01 8.82600e-02 1.58760e-01
#  9.16400e-02 1.95390e-01 7.89600e-02 9.51200e-02 1.01530e-01 8.70700e-02
# ...

# %% [markdown]
# ## Welche der Variablen sind kategorisch?
# Bei kategorische Variablen lassen sich alle Variablen in diskrete Klassen aufteilen. Nur in den Spalten RAD und CHAS sind eindeutige Klassen erkennbar
#
# ## Welche der Variablen eignen sich gut zur Vorhersage des Hauspreises und warum?
# LSTAT
# RM
# CRIM
#
# Durch die Korrelation entsteht ein Trend in ein Richtung, welcher sich durch eine Regression gut ermitteln und weiterführen lässt?
#
# ## Welche dieser Variablen sind miteinander korreliert?
# DIS / NOX
# INDUS / DIS
# CRIM / DIS
# CRIM / AGE
# DIS / B
#
#
# ## Welche sind daher Kandidaten,die man evtl. weglassen könnte?
# Durch die Korrelationen in den Daten können Variablen welche stark / eindeutig mit DIS korrelieren weggelassen werden, da die Werte mit einer gewissen Toleranz vorherbestimmt werden können.

# %%
# %reload_ext version_information
# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.5.5 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 6.5.0
# OS Windows 10 10.0.18362 SP0
# numpy 1.15.0
# pandas 0.23.3
# Mon Oct 14 10:51:55 2019 Mitteleuropäische Sommerzeit
